# %% [markdown]
# ### Análise Exploratória de Dados

# %% [markdown]
# #### Conjunto de dados: Imdb

# %% [markdown]
# #### Preparação
#  - Carregamento de bibliotecas
#  - Leitura do conjunto de dados

# %%
import pandas as pd
from IPython.display import Markdown
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

df = pd.read_csv("dados_imdb.csv")

# %% [markdown]
# #### Informações iniciais

# %%
display(Markdown("### Primeiras linhas"))
display(df.head())

display(Markdown("### Ultimas linhas"))
display(df.tail())

display(Markdown("### Informação das variáveis"))
df.info()

display(Markdown("### Quantidade de valores únicos"))
display(df.nunique())

display(Markdown("### Quantidade de valores ausentes"))
display(df.isna().sum())

display(Markdown("### Quantidade de duplicatas"))
display(df.duplicated().sum())
# Out:
# ### Primeiras linhas
#    Unnamed: 0                                   Series_Title Released_Year  \
# 0           1                                  The Godfather          1972
# 1           2                                The Dark Knight          2008
# 2           3                         The Godfather: Part II          1974
# 3           4                                   12 Angry Men          1957
# 4           5  The Lord of the Rings: The Return of the King          2003
#
#   Certificate  Runtime                     Genre  IMDB_Rating  \
# 0           A  175 min              Crime, Drama          9.2
# 1          UA  152 min      Action, Crime, Drama          9.0
# 2           A  202 min              Crime, Drama          9.0
# 3           U   96 min              Crime, Drama          9.0
# 4           U  201 min  Action, Adventure, Drama          8.9
#
#                                             Overview  Meta_score  \
# ...

# %% [markdown]
# ### Tratamento de colunas

# %% [markdown]
# #### Retirando colunas inúteis

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# #### Tratando o tipo das colunas Released_Year, Runtime e Gross

# %%
#Convertendo a coluna para numérica, transformando erros em NaN
df['Released_Year'] = pd.to_numeric(df['Released_Year'], errors='coerce')
df['Released_Year'] = df['Released_Year'].astype('Int64')

#Transformando a coluna em string para que possa ser removido o "min"
df['Runtime'] = df['Runtime'].astype(str)
df['Runtime'] = df['Runtime'].str.replace(' min', '')
df['Runtime'] = pd.to_numeric(df['Runtime'], errors='coerce') #convertendo para numérico

#Retirando as vírgulas e transformando em numérico
df['Gross'] = df['Gross'].astype(str).str.replace(',', '', regex=False)
df['Gross'] = pd.to_numeric(df['Gross'], errors='coerce')

# %% [markdown]
# #### Tratando valores nulos nas colunas Meta_score e Gross

# %%
mediana_meta_score = df['Meta_score'].median()
mediana_gross = df['Gross'].median()

df['Meta_score_original'] = df['Meta_score']
df['Gross_original'] = df['Gross']

#Preenchendo valores nulos da coluna com a mediana
df['Meta_score']= df['Meta_score'].fillna(mediana_meta_score)
df['Gross'] = df['Gross'].fillna(mediana_gross)

# %% [markdown]
# #### Tratando a coluna Certificate

# %%
contagem_valores = df['Certificate'].value_counts()
print(contagem_valores)
# Out:
# Certificate
# Adultos                345
# Universal              291
# Orientação Parental    259
# Não Classificado       104
# Name: count, dtype: int64

# %%
padronizacao = {
    'U': 'Universal',
    'UA': 'Orientação Parental',
    'U/A': 'Orientação Parental',
    'PG': 'Orientação Parental',
    'PG-13': 'Orientação Parental',
    'A': 'Adultos',
    'R': 'Adultos',
    'Passed': 'Universal',
    'Approved': 'Universal',
    'G': 'Universal',
    'Unrated': 'Não Classificado',
    'GP': 'Não Classificado',
    '16': 'Adultos',
    'TV-PG': 'Orientação Parental',
    'TV-14': 'Adultos',
    'TV-MA': 'Adultos'
}


df['Certificate'] = df['Certificate'].replace(padronizacao)
df['Certificate'].fillna('Não Classificado', inplace=True)
# Out:
# C:\Users\ClaraAguiar\AppData\Local\Temp\ipykernel_8884\2229316845.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Certificate'].fillna('Não Classificado', inplace=True)

# %%
contagem_valores = df['Certificate'].value_counts()
print(contagem_valores)
# Out:
# Certificate
# Adultos                345
# Universal              291
# Orientação Parental    259
# Não Classificado       104
# Name: count, dtype: int64

# %%
contagem_valores = df['Genre'].value_counts()
print(contagem_valores)
# Out:
# Genre
# Drama                        84
# Drama, Romance               37
# Comedy, Drama                35
# Comedy, Drama, Romance       31
# Action, Crime, Drama         30
#                              ..
# Action, Adventure, Family     1
# Action, Crime, Mystery        1
# Animation, Drama, Romance     1
# Drama, War, Western           1
# Adventure, Comedy, War        1
# Name: count, Length: 202, dtype: int64

# %% [markdown]
# #### Tratando a coluna Genre com One-hot-enconding

# %%
#Novo DataFrame com colunas para cada gênero.
generos_separados = df['Genre'].str.get_dummies(sep=', ')


df = pd.concat([df, generos_separados], axis=1) #dataframes unidos lado a lado

# %% [markdown]
# ### Colunas

# %% [markdown]
# #### Análise das Colunas Qualitativas

# %%
qualitativas = ['Director', 'Star1', 'Star2', 'Star3', 'Star4', 'Genre']

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20, 14))
axes = axes.flatten()

for i, variavel in enumerate(qualitativas):
    if variavel == 'Genre':
        # Gênero usa get_dummies para contar as categorias por conta do one-hot-enconding
        frequencia = df[variavel].str.get_dummies(sep=', ').sum().sort_values(ascending=False).head(10)
    else:
        frequencia = df[variavel].value_counts().head(10)

    ax = sns.barplot(x=frequencia.values, y=frequencia.index, ax=axes[i], color='teal')
    ax.bar_label(ax.containers[0], fmt="%d", label_type="edge", padding=5)
    ax.set_title(f"Top 10 mais frequentes: {variavel}", fontsize=14, weight='bold')
    ax.set_xlabel("Contagem", fontsize=12)
    ax.set_ylabel("", fontsize=12)
    
    # bordas desnecessárias
    for side in ["bottom", "top", "right"]:
        ax.spines[side].set_visible(False)
    ax.spines["left"].set_color("black")

plt.suptitle("Análise de Frequência das Variáveis Qualitativas\n", fontsize=20, weight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#  - O gênero Drama é o mais frequente (723), seguido por Comédia (253) e Crime (209)
#  - A estrela 1 (Ator/Atriz 1) é a que possui mais atores frequentes com o seu primeiro lugar aparecendo 12 vezes enquanto o ator 2 mais frequente só aparece 7 vezes.
# ---

# %% [markdown]
# #### Análise das Variáveis Quantitativas

# %%
quantitativas = ['IMDB_Rating', 'Meta_score', 'Released_Year', 'Runtime', 'Gross', 'No_of_Votes']

fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 10))
axes = axes.flatten()

for i, variavel in enumerate(quantitativas):
    media_variavel = df[variavel].mean()
    moda_variavel = df[variavel].median()
    ax = sns.histplot(data=df, x=variavel, kde=True, ax=axes[i], color='teal', bins=20)
    ax.axvline(media_variavel, color='red', linestyle='--', label=f'Média: {media_variavel:.2f}')
    ax.axvline(moda_variavel, color='black', linestyle='-', label=f'Mediana: {moda_variavel:.2f}')
    ax.set_title(f"Distribuição de {variavel}", fontsize=14, weight='bold')
    ax.set_xlabel(variavel, fontsize=12)
    ax.set_ylabel("Contagem", fontsize=12)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# - Pode-se perceber que a média das notas do IMDB é de 7,95, com poucos filmes alcançando nota maior que 8,8. Enquanto isso, a média ponderada de todas as críticas é de 78,13 (em uma escala de 0 a 100), o que sugere que a opinião do público e da crítica está alinhada. A média do público se mostra ligeiramente mais favorável.
#  - Apesar da média do ano de lançamento ser 1999, pode-se perceber que entre 2000 e 2020 houve um aumento na quantidade de filmes lançados.
#  - O faturamento dos filmes (Gross) apresenta uma distribuição bastante assimétrica, com a média de aproximadamente 60,5 milhões e a mediana de 23,4 milhões. Essa diferença indica que um pequeno número de filmes obteve um faturamento muito alto, enquanto a maioria se concentra em valores menores, próximos à mediana.
#  - O mesmo padrão de assimetria se repete com o número de votos. A média é puxada para valores mais altos por um grupo de filmes de grande sucesso, mas por não representarem a maioria, a mediana permanece no início do gráfico. Isso demonstra que a maioria dos filmes possui um número de votos significativamente menor.
# ---

# %% [markdown]
# #### Análise Bivariada

# %% [markdown]
# ##### Variáveis Quantitativas

# %%
import itertools
combinacoes = list(itertools.combinations(quantitativas, 2))

ncols = 3
nrows = (len(combinacoes) + ncols - 1) // ncols
fig, axes = plt.subplots(figsize=(18, 4 * nrows), ncols=ncols, nrows=nrows)
axes = axes.flatten()

for i, (var_1, var_2) in enumerate(combinacoes):
    ax = sns.scatterplot(data=df, x=var_1, y=var_2, ax=axes[i], alpha=0.6)
    ax.set(title=f"Relação entre {var_2} e {var_1}")
    ax.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Análise do Faturamento

# %% [markdown]
# Hipótese:  O gênero mais frequente (Drama) é o que possui o maior faturamento (Gross)?

# %%
top_10_filmes = df.sort_values(by='Gross', ascending=False).head(10)
top_generos = generos_separados.sum().sort_values(ascending=False).head(10).index.tolist()
faturamento_diretor = df.groupby('Director')['Gross'].mean().sort_values(ascending=False).head(10)

faturamento_medio_por_genero = {}
for genero in top_generos:
    faturamento_medio = df.loc[generos_separados[genero] == 1, 'Gross'].mean()
    faturamento_medio_por_genero[genero] = faturamento_medio

df_faturamento = pd.DataFrame(
    list(faturamento_medio_por_genero.items()),
    columns=['Gênero', 'Faturamento_Medio']
).sort_values(by='Faturamento_Medio', ascending=False)


# Gráficos
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(24, 8))

sns.barplot(x='Gross',y='Series_Title',data=top_10_filmes,ax=axes[0],color='teal')
axes[0].bar_label(axes[0].containers[0], fmt="%d", label_type="edge", padding=5)
axes[0].set_title('Top 10 Filmes com Maior Faturamento', fontsize=14, weight='bold')
axes[0].set_xlabel('Faturamento (Gross)', fontsize=12)
axes[0].set_ylabel('Nome do Filme', fontsize=12)
axes[0].grid(axis='x', linestyle='--', alpha=0.7)

# removendo bordas
for side in ["bottom", "top", "right"]:
    axes[0].spines[side].set_visible(False)
axes[0].spines["left"].set_color("black")


sns.barplot(x='Faturamento_Medio', y='Gênero', data=df_faturamento, ax=axes[1], color='teal')
axes[1].bar_label(axes[1].containers[0], fmt="%d", label_type="edge", padding=5)
axes[1].set_title('Faturamento Médio dos 10 Principais Gêneros', fontsize=14, weight='bold')
axes[1].set_xlabel('Faturamento Médio (Gross)', fontsize=12)
axes[1].set_ylabel('Gênero', fontsize=12)

for side in ["bottom", "top", "right"]:
    axes[1].spines[side].set_visible(False)
axes[1].spines["left"].set_color("black")


sns.barplot(x=faturamento_diretor.values, y=faturamento_diretor.index, ax=axes[2], color='teal')
axes[2].bar_label(axes[2].containers[0], fmt="%d", label_type="edge", padding=5)
axes[2].set_title('Faturamento Médio dos 10 Principais Diretores', fontsize=14, weight='bold')
axes[2].set_xlabel('Faturamento Médio (Gross)', fontsize=12)
axes[2].set_ylabel('Diretor',fontsize=12)

for side in ["bottom", "top", "right"]:
    axes[2].spines[side].set_visible(False)
axes[2].spines["left"].set_color("black")


plt.suptitle("Análise de Sucesso Financeiro: Filmes, Gêneros e Diretores\n", fontsize=20, weight='bold')
plt.tight_layout()

# %% [markdown]
# ---
# - Com o segundo gráfico é possível afirmar que os gêneros mais rentáveis são: Aventura, Ação e Animação, respectivamente, os outros gêneros possuem um faturamento médio mmuito abaixo dos três. O gênero mais frequente (Drama), está no sétimo lugar da lista, indicando que mais filmes de aventura devem ser produzidos.
# ---

# %%
#numero de votos por genero x diretor x filme
top_10_filmes = df.sort_values(by='Gross', ascending=False).head(10)
top_generos = generos_separados.sum().sort_values(ascending=False).head(10).index.tolist()
numero_votos_diretor = df.groupby('Director')['No_of_Votes'].mean().sort_values(ascending=False).head(10)

votos_medio_por_genero = {}
for genero in top_generos:
    votos_medio = df.loc[df[genero] == 1, 'No_of_Votes'].mean()
    votos_medio_por_genero[genero] = votos_medio

df_votos = pd.DataFrame(
    list(votos_medio_por_genero.items()),
    columns=['Gênero', 'votos_Medio']
).sort_values(by='votos_Medio', ascending=False)


# Gráficos
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(24, 8))

sns.barplot(x='No_of_Votes',y='Series_Title',data=top_10_filmes,order =top_10_filmes.sort_values(by='No_of_Votes', ascending=False)['Series_Title'],
            ax=axes[0],color='teal')
axes[0].bar_label(axes[0].containers[0], fmt="%d", label_type="edge", padding=5)
axes[0].set_title('Top 10 Filmes com Maior Número de Votos', fontsize=14, weight='bold')
axes[0].set_xlabel('Número de Votos', fontsize=12)
axes[0].set_ylabel('Nome do Filme', fontsize=12)
axes[0].grid(axis='x', linestyle='--', alpha=0.7)

# removendo bordas
for side in ["bottom", "top", "right"]:
    axes[0].spines[side].set_visible(False)
axes[0].spines["left"].set_color("black")


sns.barplot(x='votos_Medio', y='Gênero', data=df_votos, ax=axes[1], color='teal')
axes[1].bar_label(axes[1].containers[0], fmt="%d", label_type="edge", padding=5)
axes[1].set_title('Número de Votos Médio dos 10 Principais Gêneros', fontsize=14, weight='bold')
axes[1].set_xlabel('Número de Votos Médio', fontsize=12)
axes[1].set_ylabel('Gênero', fontsize=12)

for side in ["bottom", "top", "right"]:
    axes[1].spines[side].set_visible(False)
axes[1].spines["left"].set_color("black")


sns.barplot(x=numero_votos_diretor.values, y=numero_votos_diretor.index, ax=axes[2], color='teal')
axes[2].bar_label(axes[2].containers[0], fmt="%d", label_type="edge", padding=5)
axes[2].set_title('Número de Votos dos 10 Principais Diretores', fontsize=14, weight='bold')
axes[2].set_xlabel('Número de Votos Médio', fontsize=12)
axes[2].set_ylabel('Diretor',fontsize=12)

for side in ["bottom", "top", "right"]:
    axes[2].spines[side].set_visible(False)
axes[2].spines["left"].set_color("black")


plt.suptitle("Análise do Número de Votos: Filmes, Gêneros e Diretores\n", fontsize=20, weight='bold')
plt.tight_layout()

# %% [markdown]
# ---
# - Com esses gráficos podemos inferir que o filme com o maior número de votos(The Dark Knight) não é o filme mais rentável (Star Wars), como visto no gráfico anterior.
# - Em contrapartida, aventura e e ação que estavam no top três gêneros mais rentáveis também estou no ranking dos maiss votados.
# ---

# %% [markdown]
# #### Hipóteses

# %% [markdown]
# ---
#  - Existe uma relação direta entre o número de votos (No_of_Votes) e o faturamento (Gross)?
#  - Gêneros com maior número de votos tendem a ser mais lucrativos?
#  - O faturamento de um filme tem alguma relação com o seu ano de lançamento?
# ---

# %%
colunas_de_genero = df.columns[df.columns.get_loc('Action'):]
colunas_focadas = quantitativas + list(colunas_de_genero)
df_foco = df[colunas_focadas]

# Matriz de correlação
corr = df_foco.corr()

#Matriz de máscara para esconder a parte superior do triângulo
mask = np.triu(np.ones_like(corr, dtype=bool))

# figura e o heatmap
plt.figure(figsize=(15, 12))
sns.heatmap(
    corr, mask=mask,annot=True,fmt=".2f",cmap='coolwarm',vmax=1,vmin=-1,center=0,square=True,linewidths=.5,
    cbar_kws={"shrink": .5}
)

plt.title('Matriz de Correlação: Variáveis Quantitativas vs. Gêneros', fontsize=16, weight='bold')
plt.show()

# %% [markdown]
# ---
#  - O número de votos (No_of_Votes) e o faturamento (Gross) possuem uma correlação positiva de 0.60. Ou seja, há uma relação direta entre a popularidade de um filme (medida pelo número de votos) e seu sucesso financeiro.
#  -  O número de votos (No_of_Votes) e o IMDB_Rating possuem uma correlação positiva de 0.48, logo a popularidade do filme e a sua nota do IMDB possuem uma correlação.
#  - O gênero mais frequente (Drama) possui correlação  de -0.29 com o faturamento(Gross). Portanto, embora o gênero mais produzido seja drama, ele não está entre o mais lucrativos
#  - O gênero mais lucrativo apresentado foi Aventura com uma correlação de 0.42 com o faturamento, seguido por ação com correlação de 0.29, indicando serem os gêneros mais lucrativos.
#  - Os gêneros com maiores números de votos são: Aventura (0.24) e Ficção Ciêntifica (0.24), seguidos por Ação (0.20) que possuem correlação com o lucro de (0.42), (0.20), (0.29) respectivamente, os três são os gêneros com maior faturamento indicando que os gêneros com mais votos (mais populares) são os mais lucrativos.
#  - O ano de lançamento tem uma correlação de (0.14) com o faturamento que indica correlção, mas não muito alta.
#  - O ano de lançamento  tem uma correlação de (0.17) com o tempo de duração do filme, (0.25) com o número de votos e (0.24) com a nota do IMDB. Indicando que a interação e o engajamento do público com os filmes estão crescendo ao longo do tempo.
# ---

# %%
df.to_csv("dataset_tratado.csv", index =False)

# %% [markdown]
# ### Análise com Perguntas

# %% [markdown]
# #### Qual filme você recomendaria para uma pessoa que você não conhece?

# %%
limite_votos = df['No_of_Votes'].quantile(0.90)
df_altos_votos = df[df['No_of_Votes'] >= limite_votos]
recomendacoes = df_altos_votos.sort_values(by='IMDB_Rating', ascending=False).head(10)

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 8))


sns.barplot(
    x='IMDB_Rating',
    y='Series_Title',
    data=recomendacoes,
    ax=axes[0],
    color = 'teal'
)
axes[0].set_title('Top 10 Filmes com Maior Nota (IMDb)', fontsize=14, weight='bold')
axes[0].set_xlabel('Nota (IMDb)')
axes[0].set_ylabel('Filme')
axes[0].grid(axis='x', linestyle='--', alpha=0.7)

for side in ["bottom", "top", "right"]:
    axes[0].spines[side].set_visible(False)
axes[0].spines["left"].set_color("black")


sns.barplot(x='No_of_Votes', y='Series_Title', data=recomendacoes,ax=axes[1],color = 'teal')
axes[1].set_title('Top 10 Filmes com Maior Número de Votos', fontsize=14, weight='bold')
axes[1].set_xlabel('Número de Votos')
axes[1].set_ylabel('') 
axes[1].grid(axis='x', linestyle='--', alpha=0.7)

for side in ["bottom", "top", "right"]:
    axes[1].spines[side].set_visible(False)
axes[1].spines["left"].set_color("black")

plt.suptitle("Recomendações: Os Filmes mais bem Avaliados e Populares", fontsize=20, weight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#  -  Ao Analisar ambos os gráficos lado a lado é possível afirmar que o filme que tem o maior número de votos e maior nota do IMDB é ***The Dark Knight***. Portando, como estamos tratando de uma pessoa que não sabemos nenhuma informação sobre, o melhor filme para se indicar é The Dark Knight por ser o favorito do público e ter a maior nota de qualidade.
# ---

# %% [markdown]
# #### Quais são os principais fatores que estão relacionados com alta expectativa de faturamento de um filme?

# %% [markdown]
#  ---
#  - O principal fator para o alto faturamento é a sua popularidade (No_of_Votes) com correlação de 0.60
#  - O segundo fator é o seu gênero. Filmes do gênero aventura possuem o maior faturamento (correlação de 0.42), seguidos por ação (0.29) e ficção ciêntifica (0.20)
#  - Outro fator é o seu tempo (Runtime) com correlação de 0.23
#  ---

# %% [markdown]
# #### Quais insights podem ser tirados com a coluna Overview? É possível inferir o gênero do filme a partir dessa coluna?

# %% [markdown]
# ---
# - Sim, é possível descobrir o gênero de um filme a partir do seu Overview, pois as palavras e a linguagem usadas na sinopse de um filme de ação são, por exemplo, muito diferentes das usadas em um filme de romance, o que permite que um modelo de machine learning aprenda a classificar o gênero do filme através de técnicas de Processamento de Linguagem Natural (NLP).
# ---
